# %%
import random
player = 'O'
computer = 'X'

board = {
    (0,0):1,
    (0,1):2,
    (0,2):3,
    (1,0):4,
    (1,1):5,
    (1,2):6,
    (2,0):7,
    (2,1):8,
    (2,2):9 }

li = list(board.values())
b = len(li)


    
def DisplayBoard(board):
    '''this function is for display the board to the consol'''
    
    
    for i in range(0,b,3):
        print('+-------+--------+-------+')
        print('|       |        |       |')
        print('|   {}   |   {}    |   {}   |'.format(li[i],li[i+1],li[i+2]))
        print('|       |        |       |')
    print('+-------+--------+-------+') 
    
    
    
    
def EnterUserMove(board):
    '''Asks the user about their move, checks the input, and updates the board according to the user's decision''' 
    


    player_move = int(input("Enter your move: "))
    y = str(li[player_move-1])
    if y != "X" and y!= "O":
        li[player_move-1] = "O"
        
    else: 
        while True:
            player_move = int(input("try again: "))
            y = str(li[player_move-1])
            if y != "X" and y!= "O":
                li[player_move-1] = "O"
                break
                
                
    VictoryFor(player)
    DisplayBoard(board)
    MakeListOfFreeFields(board)
    DrawComputerMove(board)

    
def DrawComputerMove(board):
    '''The function draws the computer's move and updates the board'''
    
   

    computer =  li[random.randint(0,9)-1]
    y = str(computer)
    if y != "X" and y!= "O":
        li[random.randint(0,9)-1] = "X"
        
    else: 
        while True:
            r =random.randint(1,9)
            y = str(r)
            if li[r-1] != "X" and li[r-1] != "O":
                li[r-1] = "X"
                break
                
                
    VictoryFor(computer)
    DisplayBoard(board)
    EnterUserMove(board)
    
    
def MakeListOfFreeFields(board):
    '''The function browses the board and builds a list of all the free squares'''
    print(li)
    
    
def VictoryFor(board):
    '''the function analyzes the board status in order to check if the player using 'O's or 'X's has won the game'''
    
    for i in range(1):
        if li[i] == li[i+1] == li[i+2] =="O" or li[i+3] == li[i+4] == li[i+5] =="O" or li[i+6] == li[i+7] == li[i+8] =="O":
            print('YOU WIN !')
            break
            
        
            
        elif li[i] == li[i+1] == li[i+2] =="X" or li[i+3] == li[i+4] == li[i+5] =="X" or li[i+6] == li[i+7] == li[i+8] =="X":
            print('YOU LOST !')
            break
    
        elif li[0] == li[3] == li[6] =="O" or li[1] == li[4] == li[7] =="O" or li[2] == li[5] == li[8] =="O":
            print('YOU WIN !')
            break
        

        elif li[0] == li[3] == li[6] =="X" or li[1] == li[4] == li[7] =="X" or li[2] == li[5] == li[8] =="X":
            print('YOU LOST !')
            break
       
            
    
        elif li[0] == li[4] == li[8] =="O" or li[2] == li[4] == li[6] =="O":
            print('YOU WIN !')
            break
           
                
                
        elif li[0] == li[4] == li[8] =="X" or li[2] == li[4] == li[6] =="X":
            print('YOU LOST !')
            break
            
        break    

DrawComputerMove(board)
# Out:
# +-------+--------+-------+
# |       |        |       |
# |   X   |   2    |   3   |
# |       |        |       |
# +-------+--------+-------+
# |       |        |       |
# |   4   |   5    |   6   |
# |       |        |       |
# +-------+--------+-------+
# |       |        |       |
# |   7   |   8    |   9   |
# |       |        |       |
# +-------+--------+-------+
# Enter your move: 2
# +-------+--------+-------+
# |       |        |       |
# |   X   |   O    |   3   |
# |       |        |       |
# +-------+--------+-------+
# |       |        |       |
# |   4   |   5    |   6   |
# |       |        |       |
# +-------+--------+-------+
# |       |        |       |
# |   7   |   8    |   9   |
# |       |        |       |
# +-------+--------+-------+
# ['X', 'O', 3, 4, 5, 6, 7, 8, 9]
# +-------+--------+-------+
# |       |        |       |
# |   X   |   O    |   3   |
# |       |        |       |
# +-------+--------+-------+
# |       |        |       |
# ...

# %%
import random
player = 'O'
computer = 'X'

board = {
    (0,0):1,
    (0,1):2,
    (0,2):3,
    (1,0):4,
    (1,1):5,
    (1,2):6,
    (2,0):7,
    (2,1):8,
    (2,2):9 }

li = list(board.values())
b = len(li)


    
def DisplayBoard(board):
    '''this function is for display the board to the consol'''
    
    
    for i in range(0,b,3):
        print('+-------+--------+-------+')
        print('|       |        |       |')
        print('|   {}   |   {}    |   {}   |'.format(li[i],li[i+1],li[i+2]))
        print('|       |        |       |')
    print('+-------+--------+-------+') 
    
    
    
    
def EnterUserMove(board):
    '''Asks the user about their move, checks the input, and updates the board according to the user's decision''' 
    


    i = int(input("Enter your move: "))
    y = str(li[i-1])
    if y != "X" and y!= "O":
        li[i-1] = "O"
        
    else: 
        while True:
            i = int(input("try again: "))
            y = str(li[i-1])
            if y != "X" and y!= "O":
                li[i-1] = "O"
                break
                
                
    VictoryFor(player)
    DisplayBoard(board)
    MakeListOfFreeFields(board)
    DrawComputerMove(board)

    
def DrawComputerMove(board):
    '''The function draws the computer's move and updates the board'''

    j = li[random.randint(0,8)]
    y = li[j]
    if y != "X" and y!= "O":
        li[j] = "X"
        
    else: 
        while True:
            i = int(input("try again: "))
            y = str(li[i-1])
            if y != "X" and y!= "O":
                li[player_move-1] = "O"
                break
                
                
    VictoryFor(computer)
    DisplayBoard(board)
    EnterUserMove(board)
    
    
def MakeListOfFreeFields(board):
    '''The function browses the board and builds a list of all the free squares'''
    print(li)
    
    
def VictoryFor(board):
    '''the function analyzes the board status in order to check if the player using 'O's or 'X's has won the game'''
    
    for i in range(1):
        if li[i] == li[i+1] == li[i+2] =="O" or li[i+3] == li[i+4] == li[i+5] =="O" or li[i+6] == li[i+7] == li[i+8] =="O":
            print('YOU WIN !')
            break
            
        elif li[i] == li[i+1] == li[i+2] =="X" or li[i+3] == li[i+4] == li[i+5] =="X" or li[i+6] == li[i+7] == li[i+8] =="X":
            print('YOU LOST !')
            break
    
        elif li[0] == li[3] == li[6] =="O" or li[1] == li[4] == li[7] =="O" or li[2] == li[5] == li[8] =="O":
            print('YOU WIN !')
            break
        

        elif li[0] == li[3] == li[6] =="X" or li[1] == li[4] == li[7] =="X" or li[2] == li[5] == li[8] =="X":
            print('YOU LOST !')
            break  
    
        elif li[0] == li[4] == li[8] =="O" or li[2] == li[4] == li[6] =="O":
            print('YOU WIN !')
            break
                
        elif li[0] == li[4] == li[8] =="X" or li[2] == li[4] == li[6] =="X":
            print('YOU LOST !')
            break
            
        break    

DrawComputerMove(board)
